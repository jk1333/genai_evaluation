# %%
import pandas as pd
from vertexai.evaluation import EvalTask
import vertexai.evaluation.metrics.pointwise_metric as pointwise_metric
# Pointwise 검사를 위한 데이터셋 준비
# Pointwise는 단일 모델의 결과에 대한 평가입니다.
data = [
    ["This account is not protected with a two-factor authentication.", 
     "2차 인증이 되지 않은 계정입니다.",
     "이중 인증으로 보호되지 않은 계정입니다."],
    ["Even the longest journey begins with a single step.",
    "천 리 길도 한 걸음부터.",
    "가장 먼 여정도 한 걸음에서 시작됩니다."],
    ["Even the longest journey begins with a single step.",
    "Лиха беда начало.",
    "Даже самая длинная дорога продолжается с одного шага."]
]
sample_df = pd.DataFrame(data, columns=['source', 'reference', 'response'])
sample_df
# Out:
#                                               source            reference  \
# 0  This account is not protected with a two-facto...  2차 인증이 되지 않은 계정입니다.
# 1  Even the longest journey begins with a single ...       천 리 길도 한 걸음부터.
# 2  Even the longest journey begins with a single ...    Лиха беда начало.
#
#                                             response
# 0                             이중 인증으로 보호되지 않은 계정입니다.
# 1                             가장 먼 여정도 한 걸음에서 시작됩니다.
# 2  Даже самая длинная дорога продолжается с одног...

# %%
import google.auth
import vertexai
_, PROJECT_ID = google.auth.default()
LOCATION = "us-central1"
vertexai.init(project=PROJECT_ID, location=LOCATION)
eval_task = EvalTask(dataset=sample_df[['source', 'reference']].rename(columns={'reference': 'response'}),
                    metrics=[pointwise_metric.MetricX(version="METRICX_24_SRC")], #"METRICX_24_SRC_REF", "METRICX_24_SRC", or "METRICX_24_REF".
                    experiment="pointwise-eval")
result_pointwise = eval_task.evaluate()
result_pointwise.metrics_table

#metricx, lower is better (0-25)
#From the paper, https://aclanthology.org/2024.wmt-1.35/
# 0 ~ 1 is good
# above 5 means undertranslation
# Out:
#
#     <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons">
#     <style>
#       .view-vertex-resource,
#       .view-vertex-resource:hover,
#       .view-vertex-resource:visited {
#         position: relative;
#         display: inline-flex;
#         flex-direction: row;
#         height: 32px;
#         padding: 0 12px;
#           margin: 4px 18px;
#         gap: 4px;
#         border-radius: 4px;
#
#         align-items: center;
#         justify-content: center;
#         background-color: rgb(255, 255, 255);
#         color: rgb(51, 103, 214);
#
#         font-family: Roboto,"Helvetica Neue",sans-serif;
#         font-size: 13px;
#         font-weight: 500;
#         text-transform: uppercase;
#         text-decoration: none !important;
#
#         transition: box-shadow 280ms cubic-bezier(0.4, 0, 0.2, 1) 0s;
#         box-shadow: 0px 3px 1px -2px rgba(0,0,0,0.2), 0px 2px 2px 0px rgba(0,0,0,0.14), 0px 1px 5px 0px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active {
#         box-shadow: 0px 5px 5px -3px rgba(0,0,0,0.2),0px 8px 10px 1px rgba(0,0,0,0.14),0px 3px 14px 2px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active .view-vertex-ripple::before {
#         position: absolute;
#         top: 0;
#         bottom: 0;
#         left: 0;
#         right: 0;
#         border-radius: 4px;
#         pointer-events: none;
#
#         content: '';
#         background-color: rgb(51, 103, 214);
#         opacity: 0.12;
#       }
#       .view-vertex-icon {
#         font-size: 18px;
#       }
#     </style>
#
#         <a class="view-vertex-resource" id="view-vertex-resource-dab82ce1-6a75-40df-b49d-d556128eca79" href="https://console.cloud.google.com/vertex-ai/experiments/locations/us-central1/experiments/pointwise-eval/runs?project=sandbox-373102" target="_blank">
#           <span class="material-icons view-vertex-icon">science</span>
#           <span>View Experiment</span>
#         </a>
#
#         <script>
#           (function () {
#             const link = document.getElementById('view-vertex-resource-dab82ce1-6a75-40df-b49d-d556128eca79');
#             link.addEventListener('click', (e) => {
#               if (window.google?.colab?.openUrl) {
#                 window.google.colab.openUrl("https://console.cloud.google.com/vertex-ai/experiments/locations/us-central1/experiments/pointwise-eval/runs?project=sandbox-373102");
#                 e.preventDefault();
#               }
#             });
#           })();
#         </script>
# Associating projects/1045259343465/locations/us-central1/metadataStores/default/contexts/pointwise-eval-21465365-95d5-4105-a750-4ac0657494f1 to Experiment: pointwise-eval
#
#     <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons">
#     <style>
#       .view-vertex-resource,
#       .view-vertex-resource:hover,
#       .view-vertex-resource:visited {
#         position: relative;
#         display: inline-flex;
#         flex-direction: row;
#         height: 32px;
#         padding: 0 12px;
#           margin: 4px 18px;
#         gap: 4px;
#         border-radius: 4px;
#
#         align-items: center;
#         justify-content: center;
#         background-color: rgb(255, 255, 255);
#         color: rgb(51, 103, 214);
#
#         font-family: Roboto,"Helvetica Neue",sans-serif;
#         font-size: 13px;
#         font-weight: 500;
#         text-transform: uppercase;
#         text-decoration: none !important;
#
#         transition: box-shadow 280ms cubic-bezier(0.4, 0, 0.2, 1) 0s;
#         box-shadow: 0px 3px 1px -2px rgba(0,0,0,0.2), 0px 2px 2px 0px rgba(0,0,0,0.14), 0px 1px 5px 0px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active {
#         box-shadow: 0px 5px 5px -3px rgba(0,0,0,0.2),0px 8px 10px 1px rgba(0,0,0,0.14),0px 3px 14px 2px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active .view-vertex-ripple::before {
#         position: absolute;
#         top: 0;
#         bottom: 0;
#         left: 0;
#         right: 0;
#         border-radius: 4px;
#         pointer-events: none;
#
#         content: '';
#         background-color: rgb(51, 103, 214);
#         opacity: 0.12;
#       }
#       .view-vertex-icon {
#         font-size: 18px;
#       }
#     </style>
#
#         <a class="view-vertex-resource" id="view-vertex-resource-d628b34b-e1a7-4b90-8959-00eae3c2a31b" href="https://console.cloud.google.com/vertex-ai/experiments/locations/us-central1/experiments/pointwise-eval/runs/pointwise-eval-21465365-95d5-4105-a750-4ac0657494f1?project=sandbox-373102" target="_blank">
#           <span class="material-icons view-vertex-icon">science</span>
#           <span>View Experiment Run</span>
#         </a>
#
#         <script>
#           (function () {
#             const link = document.getElementById('view-vertex-resource-d628b34b-e1a7-4b90-8959-00eae3c2a31b');
#             link.addEventListener('click', (e) => {
#               if (window.google?.colab?.openUrl) {
#                 window.google.colab.openUrl("https://console.cloud.google.com/vertex-ai/experiments/locations/us-central1/experiments/pointwise-eval/runs/pointwise-eval-21465365-95d5-4105-a750-4ac0657494f1?project=sandbox-373102");
#                 e.preventDefault();
#               }
#             });
#           })();
#         </script>
# Computing metrics with a total of 3 Vertex Gen AI Evaluation Service API requests.
# 100%|██████████| 3/3 [00:05<00:00,  1.71s/it]
# All 3 metric requests are successfully computed.
# Evaluation Took:5.151485299982596 seconds
#
#     <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons">
#     <style>
#       .view-vertex-resource,
#       .view-vertex-resource:hover,
#       .view-vertex-resource:visited {
#         position: relative;
#         display: inline-flex;
#         flex-direction: row;
#         height: 32px;
#         padding: 0 12px;
#           margin: 4px 18px;
#         gap: 4px;
#         border-radius: 4px;
#
#         align-items: center;
#         justify-content: center;
#         background-color: rgb(255, 255, 255);
#         color: rgb(51, 103, 214);
#
#         font-family: Roboto,"Helvetica Neue",sans-serif;
#         font-size: 13px;
#         font-weight: 500;
#         text-transform: uppercase;
#         text-decoration: none !important;
#
#         transition: box-shadow 280ms cubic-bezier(0.4, 0, 0.2, 1) 0s;
#         box-shadow: 0px 3px 1px -2px rgba(0,0,0,0.2), 0px 2px 2px 0px rgba(0,0,0,0.14), 0px 1px 5px 0px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active {
#         box-shadow: 0px 5px 5px -3px rgba(0,0,0,0.2),0px 8px 10px 1px rgba(0,0,0,0.14),0px 3px 14px 2px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active .view-vertex-ripple::before {
#         position: absolute;
#         top: 0;
#         bottom: 0;
#         left: 0;
#         right: 0;
#         border-radius: 4px;
#         pointer-events: none;
#
#         content: '';
#         background-color: rgb(51, 103, 214);
#         opacity: 0.12;
#       }
#       .view-vertex-icon {
#         font-size: 18px;
#       }
#     </style>
#
#         <a class="view-vertex-resource" id="view-vertex-resource-c17f4513-3f8b-4e20-8b81-c6f141776fe8" href="https://cloud.google.com/vertex-ai/generative-ai/docs/models/view-evaluation" target="_blank">
#           <span class="material-icons view-vertex-icon">bar_chart</span>
#           <span>View evaluation results</span>
#         </a>
#
#         <script>
#           (function () {
#             const link = document.getElementById('view-vertex-resource-c17f4513-3f8b-4e20-8b81-c6f141776fe8');
#             link.addEventListener('click', (e) => {
#               if (window.google?.colab?.openUrl) {
#                 window.google.colab.openUrl("https://cloud.google.com/vertex-ai/generative-ai/docs/models/view-evaluation");
#                 e.preventDefault();
#               }
#             });
#           })();
#         </script>
#                                               source             response  \
# 0  This account is not protected with a two-facto...  2차 인증이 되지 않은 계정입니다.
# 1  Even the longest journey begins with a single ...       천 리 길도 한 걸음부터.
# 2  Even the longest journey begins with a single ...    Лиха беда начало.
#
#    metricx/score
# 0       0.950510
# 1       0.652064
# 2       3.064888

# %%
eval_task = EvalTask(dataset=sample_df[['source', 'response']],
                    metrics=[pointwise_metric.MetricX(version="METRICX_24_SRC")],
                    experiment="pointwise-eval")
result_pointwise = eval_task.evaluate()
result_pointwise.metrics_table

#metricx, lower is better (0-25)
#From the paper, https://aclanthology.org/2024.wmt-1.35/
# 0 ~ 1 is good
# above 5 means undertranslation
# Out:
#
#     <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons">
#     <style>
#       .view-vertex-resource,
#       .view-vertex-resource:hover,
#       .view-vertex-resource:visited {
#         position: relative;
#         display: inline-flex;
#         flex-direction: row;
#         height: 32px;
#         padding: 0 12px;
#           margin: 4px 18px;
#         gap: 4px;
#         border-radius: 4px;
#
#         align-items: center;
#         justify-content: center;
#         background-color: rgb(255, 255, 255);
#         color: rgb(51, 103, 214);
#
#         font-family: Roboto,"Helvetica Neue",sans-serif;
#         font-size: 13px;
#         font-weight: 500;
#         text-transform: uppercase;
#         text-decoration: none !important;
#
#         transition: box-shadow 280ms cubic-bezier(0.4, 0, 0.2, 1) 0s;
#         box-shadow: 0px 3px 1px -2px rgba(0,0,0,0.2), 0px 2px 2px 0px rgba(0,0,0,0.14), 0px 1px 5px 0px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active {
#         box-shadow: 0px 5px 5px -3px rgba(0,0,0,0.2),0px 8px 10px 1px rgba(0,0,0,0.14),0px 3px 14px 2px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active .view-vertex-ripple::before {
#         position: absolute;
#         top: 0;
#         bottom: 0;
#         left: 0;
#         right: 0;
#         border-radius: 4px;
#         pointer-events: none;
#
#         content: '';
#         background-color: rgb(51, 103, 214);
#         opacity: 0.12;
#       }
#       .view-vertex-icon {
#         font-size: 18px;
#       }
#     </style>
#
#         <a class="view-vertex-resource" id="view-vertex-resource-fac5ed91-0ca4-4b16-abb5-a474057f1f94" href="https://console.cloud.google.com/vertex-ai/experiments/locations/us-central1/experiments/pointwise-eval/runs?project=sandbox-373102" target="_blank">
#           <span class="material-icons view-vertex-icon">science</span>
#           <span>View Experiment</span>
#         </a>
#
#         <script>
#           (function () {
#             const link = document.getElementById('view-vertex-resource-fac5ed91-0ca4-4b16-abb5-a474057f1f94');
#             link.addEventListener('click', (e) => {
#               if (window.google?.colab?.openUrl) {
#                 window.google.colab.openUrl("https://console.cloud.google.com/vertex-ai/experiments/locations/us-central1/experiments/pointwise-eval/runs?project=sandbox-373102");
#                 e.preventDefault();
#               }
#             });
#           })();
#         </script>
# Associating projects/1045259343465/locations/us-central1/metadataStores/default/contexts/pointwise-eval-358a14fd-074c-4b72-bd96-5018db3c0bdd to Experiment: pointwise-eval
#
#     <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons">
#     <style>
#       .view-vertex-resource,
#       .view-vertex-resource:hover,
#       .view-vertex-resource:visited {
#         position: relative;
#         display: inline-flex;
#         flex-direction: row;
#         height: 32px;
#         padding: 0 12px;
#           margin: 4px 18px;
#         gap: 4px;
#         border-radius: 4px;
#
#         align-items: center;
#         justify-content: center;
#         background-color: rgb(255, 255, 255);
#         color: rgb(51, 103, 214);
#
#         font-family: Roboto,"Helvetica Neue",sans-serif;
#         font-size: 13px;
#         font-weight: 500;
#         text-transform: uppercase;
#         text-decoration: none !important;
#
#         transition: box-shadow 280ms cubic-bezier(0.4, 0, 0.2, 1) 0s;
#         box-shadow: 0px 3px 1px -2px rgba(0,0,0,0.2), 0px 2px 2px 0px rgba(0,0,0,0.14), 0px 1px 5px 0px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active {
#         box-shadow: 0px 5px 5px -3px rgba(0,0,0,0.2),0px 8px 10px 1px rgba(0,0,0,0.14),0px 3px 14px 2px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active .view-vertex-ripple::before {
#         position: absolute;
#         top: 0;
#         bottom: 0;
#         left: 0;
#         right: 0;
#         border-radius: 4px;
#         pointer-events: none;
#
#         content: '';
#         background-color: rgb(51, 103, 214);
#         opacity: 0.12;
#       }
#       .view-vertex-icon {
#         font-size: 18px;
#       }
#     </style>
#
#         <a class="view-vertex-resource" id="view-vertex-resource-fe9c6826-5c81-474b-9f01-acd542e287bc" href="https://console.cloud.google.com/vertex-ai/experiments/locations/us-central1/experiments/pointwise-eval/runs/pointwise-eval-358a14fd-074c-4b72-bd96-5018db3c0bdd?project=sandbox-373102" target="_blank">
#           <span class="material-icons view-vertex-icon">science</span>
#           <span>View Experiment Run</span>
#         </a>
#
#         <script>
#           (function () {
#             const link = document.getElementById('view-vertex-resource-fe9c6826-5c81-474b-9f01-acd542e287bc');
#             link.addEventListener('click', (e) => {
#               if (window.google?.colab?.openUrl) {
#                 window.google.colab.openUrl("https://console.cloud.google.com/vertex-ai/experiments/locations/us-central1/experiments/pointwise-eval/runs/pointwise-eval-358a14fd-074c-4b72-bd96-5018db3c0bdd?project=sandbox-373102");
#                 e.preventDefault();
#               }
#             });
#           })();
#         </script>
# Computing metrics with a total of 3 Vertex Gen AI Evaluation Service API requests.
# 100%|██████████| 3/3 [00:04<00:00,  1.64s/it]
# All 3 metric requests are successfully computed.
# Evaluation Took:4.931300800002646 seconds
#
#     <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons">
#     <style>
#       .view-vertex-resource,
#       .view-vertex-resource:hover,
#       .view-vertex-resource:visited {
#         position: relative;
#         display: inline-flex;
#         flex-direction: row;
#         height: 32px;
#         padding: 0 12px;
#           margin: 4px 18px;
#         gap: 4px;
#         border-radius: 4px;
#
#         align-items: center;
#         justify-content: center;
#         background-color: rgb(255, 255, 255);
#         color: rgb(51, 103, 214);
#
#         font-family: Roboto,"Helvetica Neue",sans-serif;
#         font-size: 13px;
#         font-weight: 500;
#         text-transform: uppercase;
#         text-decoration: none !important;
#
#         transition: box-shadow 280ms cubic-bezier(0.4, 0, 0.2, 1) 0s;
#         box-shadow: 0px 3px 1px -2px rgba(0,0,0,0.2), 0px 2px 2px 0px rgba(0,0,0,0.14), 0px 1px 5px 0px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active {
#         box-shadow: 0px 5px 5px -3px rgba(0,0,0,0.2),0px 8px 10px 1px rgba(0,0,0,0.14),0px 3px 14px 2px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active .view-vertex-ripple::before {
#         position: absolute;
#         top: 0;
#         bottom: 0;
#         left: 0;
#         right: 0;
#         border-radius: 4px;
#         pointer-events: none;
#
#         content: '';
#         background-color: rgb(51, 103, 214);
#         opacity: 0.12;
#       }
#       .view-vertex-icon {
#         font-size: 18px;
#       }
#     </style>
#
#         <a class="view-vertex-resource" id="view-vertex-resource-e4bae7dc-cd0e-46e4-afc6-09929bf7dbbe" href="https://cloud.google.com/vertex-ai/generative-ai/docs/models/view-evaluation" target="_blank">
#           <span class="material-icons view-vertex-icon">bar_chart</span>
#           <span>View evaluation results</span>
#         </a>
#
#         <script>
#           (function () {
#             const link = document.getElementById('view-vertex-resource-e4bae7dc-cd0e-46e4-afc6-09929bf7dbbe');
#             link.addEventListener('click', (e) => {
#               if (window.google?.colab?.openUrl) {
#                 window.google.colab.openUrl("https://cloud.google.com/vertex-ai/generative-ai/docs/models/view-evaluation");
#                 e.preventDefault();
#               }
#             });
#           })();
#         </script>
#                                               source  \
# 0  This account is not protected with a two-facto...
# 1  Even the longest journey begins with a single ...
# 2  Even the longest journey begins with a single ...
#
#                                             response  metricx/score
# 0                             이중 인증으로 보호되지 않은 계정입니다.       0.640757
# 1                             가장 먼 여정도 한 걸음에서 시작됩니다.       0.894905
# 2  Даже самая длинная дорога продолжается с одног...       4.401481

# %%
eval_task = EvalTask(dataset=sample_df[['source', 'reference', 'response']],
                    metrics=[pointwise_metric.Comet(version="COMET_22_SRC_REF")],
                    experiment="pointwise-eval")
result_pointwise = eval_task.evaluate()
result_pointwise.metrics_table

#comet, higher is better (0-1)
#From the paper, https://aclanthology.org/2022.wmt-1.52
# Out:
#
#     <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons">
#     <style>
#       .view-vertex-resource,
#       .view-vertex-resource:hover,
#       .view-vertex-resource:visited {
#         position: relative;
#         display: inline-flex;
#         flex-direction: row;
#         height: 32px;
#         padding: 0 12px;
#           margin: 4px 18px;
#         gap: 4px;
#         border-radius: 4px;
#
#         align-items: center;
#         justify-content: center;
#         background-color: rgb(255, 255, 255);
#         color: rgb(51, 103, 214);
#
#         font-family: Roboto,"Helvetica Neue",sans-serif;
#         font-size: 13px;
#         font-weight: 500;
#         text-transform: uppercase;
#         text-decoration: none !important;
#
#         transition: box-shadow 280ms cubic-bezier(0.4, 0, 0.2, 1) 0s;
#         box-shadow: 0px 3px 1px -2px rgba(0,0,0,0.2), 0px 2px 2px 0px rgba(0,0,0,0.14), 0px 1px 5px 0px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active {
#         box-shadow: 0px 5px 5px -3px rgba(0,0,0,0.2),0px 8px 10px 1px rgba(0,0,0,0.14),0px 3px 14px 2px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active .view-vertex-ripple::before {
#         position: absolute;
#         top: 0;
#         bottom: 0;
#         left: 0;
#         right: 0;
#         border-radius: 4px;
#         pointer-events: none;
#
#         content: '';
#         background-color: rgb(51, 103, 214);
#         opacity: 0.12;
#       }
#       .view-vertex-icon {
#         font-size: 18px;
#       }
#     </style>
#
#         <a class="view-vertex-resource" id="view-vertex-resource-395f55cd-5ba8-481c-aff9-b67ab1a8510c" href="https://console.cloud.google.com/vertex-ai/experiments/locations/us-central1/experiments/pointwise-eval/runs?project=sandbox-373102" target="_blank">
#           <span class="material-icons view-vertex-icon">science</span>
#           <span>View Experiment</span>
#         </a>
#
#         <script>
#           (function () {
#             const link = document.getElementById('view-vertex-resource-395f55cd-5ba8-481c-aff9-b67ab1a8510c');
#             link.addEventListener('click', (e) => {
#               if (window.google?.colab?.openUrl) {
#                 window.google.colab.openUrl("https://console.cloud.google.com/vertex-ai/experiments/locations/us-central1/experiments/pointwise-eval/runs?project=sandbox-373102");
#                 e.preventDefault();
#               }
#             });
#           })();
#         </script>
# Associating projects/1045259343465/locations/us-central1/metadataStores/default/contexts/pointwise-eval-d775698f-80fd-4b52-9e7e-ab7b7de9a39c to Experiment: pointwise-eval
#
#     <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons">
#     <style>
#       .view-vertex-resource,
#       .view-vertex-resource:hover,
#       .view-vertex-resource:visited {
#         position: relative;
#         display: inline-flex;
#         flex-direction: row;
#         height: 32px;
#         padding: 0 12px;
#           margin: 4px 18px;
#         gap: 4px;
#         border-radius: 4px;
#
#         align-items: center;
#         justify-content: center;
#         background-color: rgb(255, 255, 255);
#         color: rgb(51, 103, 214);
#
#         font-family: Roboto,"Helvetica Neue",sans-serif;
#         font-size: 13px;
#         font-weight: 500;
#         text-transform: uppercase;
#         text-decoration: none !important;
#
#         transition: box-shadow 280ms cubic-bezier(0.4, 0, 0.2, 1) 0s;
#         box-shadow: 0px 3px 1px -2px rgba(0,0,0,0.2), 0px 2px 2px 0px rgba(0,0,0,0.14), 0px 1px 5px 0px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active {
#         box-shadow: 0px 5px 5px -3px rgba(0,0,0,0.2),0px 8px 10px 1px rgba(0,0,0,0.14),0px 3px 14px 2px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active .view-vertex-ripple::before {
#         position: absolute;
#         top: 0;
#         bottom: 0;
#         left: 0;
#         right: 0;
#         border-radius: 4px;
#         pointer-events: none;
#
#         content: '';
#         background-color: rgb(51, 103, 214);
#         opacity: 0.12;
#       }
#       .view-vertex-icon {
#         font-size: 18px;
#       }
#     </style>
#
#         <a class="view-vertex-resource" id="view-vertex-resource-7fc37cfe-3ecc-441a-9fc6-01e39dc240fd" href="https://console.cloud.google.com/vertex-ai/experiments/locations/us-central1/experiments/pointwise-eval/runs/pointwise-eval-d775698f-80fd-4b52-9e7e-ab7b7de9a39c?project=sandbox-373102" target="_blank">
#           <span class="material-icons view-vertex-icon">science</span>
#           <span>View Experiment Run</span>
#         </a>
#
#         <script>
#           (function () {
#             const link = document.getElementById('view-vertex-resource-7fc37cfe-3ecc-441a-9fc6-01e39dc240fd');
#             link.addEventListener('click', (e) => {
#               if (window.google?.colab?.openUrl) {
#                 window.google.colab.openUrl("https://console.cloud.google.com/vertex-ai/experiments/locations/us-central1/experiments/pointwise-eval/runs/pointwise-eval-d775698f-80fd-4b52-9e7e-ab7b7de9a39c?project=sandbox-373102");
#                 e.preventDefault();
#               }
#             });
#           })();
#         </script>
# Computing metrics with a total of 3 Vertex Gen AI Evaluation Service API requests.
# 100%|██████████| 3/3 [00:03<00:00,  1.03s/it]
# All 3 metric requests are successfully computed.
# Evaluation Took:3.3337916000164114 seconds
#
#     <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons">
#     <style>
#       .view-vertex-resource,
#       .view-vertex-resource:hover,
#       .view-vertex-resource:visited {
#         position: relative;
#         display: inline-flex;
#         flex-direction: row;
#         height: 32px;
#         padding: 0 12px;
#           margin: 4px 18px;
#         gap: 4px;
#         border-radius: 4px;
#
#         align-items: center;
#         justify-content: center;
#         background-color: rgb(255, 255, 255);
#         color: rgb(51, 103, 214);
#
#         font-family: Roboto,"Helvetica Neue",sans-serif;
#         font-size: 13px;
#         font-weight: 500;
#         text-transform: uppercase;
#         text-decoration: none !important;
#
#         transition: box-shadow 280ms cubic-bezier(0.4, 0, 0.2, 1) 0s;
#         box-shadow: 0px 3px 1px -2px rgba(0,0,0,0.2), 0px 2px 2px 0px rgba(0,0,0,0.14), 0px 1px 5px 0px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active {
#         box-shadow: 0px 5px 5px -3px rgba(0,0,0,0.2),0px 8px 10px 1px rgba(0,0,0,0.14),0px 3px 14px 2px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active .view-vertex-ripple::before {
#         position: absolute;
#         top: 0;
#         bottom: 0;
#         left: 0;
#         right: 0;
#         border-radius: 4px;
#         pointer-events: none;
#
#         content: '';
#         background-color: rgb(51, 103, 214);
#         opacity: 0.12;
#       }
#       .view-vertex-icon {
#         font-size: 18px;
#       }
#     </style>
#
#         <a class="view-vertex-resource" id="view-vertex-resource-d81058a4-f29e-4ef4-b734-cdb229a19486" href="https://cloud.google.com/vertex-ai/generative-ai/docs/models/view-evaluation" target="_blank">
#           <span class="material-icons view-vertex-icon">bar_chart</span>
#           <span>View evaluation results</span>
#         </a>
#
#         <script>
#           (function () {
#             const link = document.getElementById('view-vertex-resource-d81058a4-f29e-4ef4-b734-cdb229a19486');
#             link.addEventListener('click', (e) => {
#               if (window.google?.colab?.openUrl) {
#                 window.google.colab.openUrl("https://cloud.google.com/vertex-ai/generative-ai/docs/models/view-evaluation");
#                 e.preventDefault();
#               }
#             });
#           })();
#         </script>
#                                               source            reference  \
# 0  This account is not protected with a two-facto...  2차 인증이 되지 않은 계정입니다.
# 1  Even the longest journey begins with a single ...       천 리 길도 한 걸음부터.
# 2  Even the longest journey begins with a single ...    Лиха беда начало.
#
#                                             response  comet/score
# 0                             이중 인증으로 보호되지 않은 계정입니다.     0.915181
# 1                             가장 먼 여정도 한 걸음에서 시작됩니다.     0.925086
# 2  Даже самая длинная дорога продолжается с одног...     0.568027
