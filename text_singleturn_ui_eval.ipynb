# %%
import pandas as pd

# Example DataFrame with prompts and ground truth references
prompts_df = pd.DataFrame({
    "prompt": [
        "What is the capital of France?",
        "Who wrote 'Hamlet'?",
    ],
    "response": [
        "Paris",
        "William Shakespeare",
    ]
})
prompts_df.to_json('single_reference.jsonl', orient='records', lines=True)

# %%
# Example DataFrame with prompts and ground truth references
prompts_df = pd.DataFrame({
    "prompt": [
        """
도움이 되는 주방 보조 역할을 맡아주세요. 제가 음식 레시피를 제공하면, 당신의 임무는 식료품점에서 사용하기 쉽게 카테고리별로 분류된 장보기 목록으로 변환하는 것입니다.

지시 사항:

아래 레시피에서 모든 재료와 필요한 수량을 주의 깊게 추출하세요.

재료를 논리적인 식료품점 카테고리(예: 청과류, 육류 및 단백질, 유제품 및 계란, 통조림류, 향신료, 베이커리)로 정리하세요.

소금, 후추, 물, 올리브유, 중력분과 같은 일반적인 가정용 품목을 위해 마지막에 "기본 양념 및 재료(Pantry Staples)"라는 별도의 카테고리를 만드세요.

선택 사항인 재료는 재료 뒤에 "선택사항"이라고 표시하세요. 재료의 가공에 관한 구체적인 상세 정보(다진 것, 깍둑썰기한 것 등)는 포함하지 마세요.

최종 출력물은 깔끔한 글머리 기호 목록 형식으로 작성하세요. 다른 출력물은 추가하지 마세요.

레시피:

간단한 그리스식 샐러드

분량: 4인분

재료: 로메인 양상추 1포기(썰어둔 것), 큰 오이 1개(깍둑썰기한 것), 방울토마토 1파인트(반으로 썬 것), 적양파 1/2개(얇게 썬 것), 칼라마타 올리브 1/2컵, 페타 치즈 4온스(으깬 것).

드레싱 재료: 올리브유 1/4컵, 레드 와인 식초 3큰술, 말린 오레가노 1작은술, 디종 머스타드 1/2작은술.

조리법: 큰 볼에 양상추, 오이, 토마토, 적양파, 올리브를 섞습니다. 작은 병에 올리브유, 레드 와인 식초, 오레가노, 머스타드를 넣고 함께 흔들어 섞습니다. 샐러드 위에 드레싱을 붓고 잘 섞은 뒤, 으깬 페타 치즈를 위에 올립니다.
        """,
        """
도움이 되는 주방 보조 역할을 맡아주세요. 제가 음식 레시피를 제공하면, 당신의 임무는 식료품점에서 사용하기 쉽게 카테고리별로 분류된 장보기 목록으로 변환하는 것입니다.

지시 사항:

아래 레시피에서 모든 재료와 필요한 수량을 주의 깊게 추출하세요.

재료를 논리적인 식료품점 카테고리(예: 청과류, 육류 및 단백질, 유제품 및 계란, 통조림류, 향신료, 베이커리)로 정리하세요.

소금, 후추, 물, 올리브유, 중력분과 같은 일반적인 가정용 품목을 위해 마지막에 "기본 양념 및 재료(Pantry Staples)"라는 별도의 카테고리를 만드세요.

선택 사항인 재료는 재료 뒤에 "선택사항"이라고 표시하세요. 재료의 가공에 관한 구체적인 상세 정보(다진 것, 깍둑썰기한 것 등)는 포함하지 마세요.

최종 출력물은 깔끔한 글머리 기호 목록 형식으로 작성하세요. 다른 출력물은 추가하지 마세요.

레시피:

클래식 비프 타코

분량: 4인분

재료: 다진 소고기 1파운드, 타코 시즈닝 1팩, 물 3/4컵, 하드 타코 쉘 8-10개, 잘게 썬 양상추 1컵, 큰 토마토 1개(깍둑썰기한 것), 잘게 썬 체다 치즈 1/2컵, 토핑용 사워크림, 토핑용 살사 소스.

조리법: 프라이팬에 카놀라유를 두르고 다진 소고기가 노릇해질 때까지 볶습니다. 기름을 빼냅니다. 타코 시즈닝과 물을 넣고 젓습니다. 뭉근하게 끓여 5분간 조리합니다. 포장지의 설명에 따라 타코 쉘을 데웁니다. 소고기, 양상추, 토마토, 치즈, 사워크림, 살사 소스를 넣고 타코를 만듭니다.
        """,
        """
도움이 되는 주방 보조 역할을 맡아주세요. 제가 음식 레시피를 제공하면, 당신의 임무는 식료품점에서 사용하기 쉽게 카테고리별로 분류된 장보기 목록으로 변환하는 것입니다.

지시 사항:

아래 레시피에서 모든 재료와 필요한 수량을 주의 깊게 추출하세요.

재료를 논리적인 식료품점 카테고리(예: 청과류, 육류 및 단백질, 유제품 및 계란, 통조림류, 향신료, 베이커리)로 정리하세요.

소금, 후추, 물, 올리브유, 중력분과 같은 일반적인 가정용 품목을 위해 마지막에 "기본 양념 및 재료(Pantry Staples)"라는 별도의 카테고리를 만드세요.

선택 사항인 재료는 재료 뒤에 "선택사항"이라고 표시하세요. 재료의 가공에 관한 구체적인 상세 정보(다진 것, 깍둑썰기한 것 등)는 포함하지 마세요.

최종 출력물은 깔끔한 글머리 기호 목록 형식으로 작성하세요. 다른 출력물은 추가하지 마세요.

레시피:

완벽한 초콜릿 칩 쿠키

분량: 24개 (2다스)

재료: 무염 버터 1컵(부드럽게 해둔 것), 흰 설탕 3/4컵, 황설탕 3/4컵(꾹 눌러 담은 것), 바닐라 추출물 1작은술, 큰 계란 2개, 중력분 2와 1/4컵, 베이킹 소다 1작은술, 소금 1/2작은술, 세미스윗 초콜릿 칩 2컵.

조리법: 버터와 설탕을 함께 크림화합니다. 바닐라와 계란을 하나씩 넣고 섞습니다. 별도의 볼에 밀가루, 베이킹 소다, 소금을 넣고 젓습니다. 마른 재료를 젖은 재료에 천천히 추가합니다. 초콜릿 칩을 넣고 저어줍니다. 숟가락으로 둥글게 떼어내어 오븐 트레이에 올립니다. 190°C(375°F)에서 9-11분간 굽습니다.
        """,
        """
도움이 되는 주방 보조 역할을 맡아주세요. 제가 음식 레시피를 제공하면, 당신의 임무는 식료품점에서 사용하기 쉽게 카테고리별로 분류된 장보기 목록으로 변환하는 것입니다.

지시 사항:

아래 레시피에서 모든 재료와 필요한 수량을 주의 깊게 추출하세요.

재료를 논리적인 식료품점 카테고리(예: 청과류, 육류 및 단백질, 유제품 및 계란, 통조림류, 향신료, 베이커리)로 정리하세요.

소금, 후추, 물, 올리브유, 중력분과 같은 일반적인 가정용 품목을 위해 마지막에 "기본 양념 및 재료(Pantry Staples)"라는 별도의 카테고리를 만드세요.

선택 사항인 재료는 재료 뒤에 "선택사항"이라고 표시하세요. 재료의 가공에 관한 구체적인 상세 정보(다진 것, 깍둑썰기한 것 등)는 포함하지 마세요.

최종 출력물은 깔끔한 글머리 기호 목록 형식으로 작성하세요. 다른 출력물은 추가하지 마세요.

레시피:

푸짐한 렌틸콩 스프 (채식)

분량: 6인분

재료: 올리브유 2큰술, 큰 노란 양파 1개(썰어둔 것), 당근 2개(깍둑썰기한 것), 셀러리 줄기 2개(깍둑썰기한 것), 마늘 3쪽(다진 것), 말린 타임 1작은술, 큐민 1/2작은술, 깍둑썰기한 토마토 통조림 1캔(28온스), 갈색 또는 초록색 렌틸콩 1.5컵(씻어둔 것), 채수 8컵, 신선한 시금치 2컵, 레몬즙 1큰술, 소금, 후추.

조리법: 큰 냄비에 양파, 당근, 셀러리를 부드러워질 때까지 볶습니다. 마늘, 타임, 큐민을 넣고 1분간 더 볶습니다. 깍둑썰기한 토마토, 렌틸콩, 채수를 넣습니다. 끓기 시작하면 불을 줄이고 렌틸콩이 부드러워질 때까지 45-50분간 뭉근하게 끓입니다. 시금치와 레몬즙을 넣고 저어줍니다. 소금과 후추로 간을 맞춥니다.
        """
    ]
})
prompts_df.to_json('single_response_free.jsonl', orient='records', lines=True)
