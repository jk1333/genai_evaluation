# %% [markdown]
# #Due to preview version of dashboard, multi turn evaluation runs on only API mode

# %%
chat_dataset = [
    # 예제 1: 여행 계획 (파리)
    {
        "request": {
            "contents": [
                {
                    "role": "user",
                    "parts": [{"text": "I'm planning a trip to Paris."}],
                },
                {
                    "role": "model",
                    "parts": [
                        {
                            "text": (
                                "That sounds wonderful! What time of year are"
                                " you going?"
                            )
                        }
                    ],
                },
                {
                    "role": "user",
                    "parts": [
                        {
                            "text": (
                                "I'm thinking next spring. What are some"
                                " must-see sights?"
                            )
                        }
                    ],
                },
            ]
        },
        "response": {
            "candidates": [
                {
                    "content": {
                        "role": "model",
                        "parts": [
                            {
                                "text": (
                                    "For spring in Paris, you should definitely"
                                    " visit the Eiffel Tower, the Louvre Museum,"
                                    " and wander through Montmartre."
                                )
                            }
                        ],
                    }
                }
            ]
        },
    },
    # 예제 2: 요리 레시피 (파스타)
    {
        "request": {
            "contents": [
                {
                    "role": "user",
                    "parts": [
                        {
                            "text": (
                                "I want to make dinner using ingredients in my"
                                " fridge."
                            )
                        }
                    ],
                },
                {
                    "role": "model",
                    "parts": [
                        {
                            "text": (
                                "I can help! What main ingredients do you have?"
                            )
                        }
                    ],
                },
                {
                    "role": "user",
                    "parts": [
                        {
                            "text": (
                                "I have chicken breast, garlic, pasta, and"
                                " cream."
                            )
                        }
                    ],
                },
            ]
        },
        "response": {
            "candidates": [
                {
                    "content": {
                        "role": "model",
                        "parts": [
                            {
                                "text": (
                                    "You can make a Creamy Garlic Chicken"
                                    " Pasta! Sauté the chicken and garlic, boil"
                                    " the pasta, and mix them together with the"
                                    " cream."
                                )
                            }
                        ],
                    }
                }
            ]
        },
    },
    # 예제 3: 코딩 질문 (Pandas)
    {
        "request": {
            "contents": [
                {
                    "role": "user",
                    "parts": [
                        {
                            "text": (
                                "How do I filter rows in a Pandas DataFrame?"
                            )
                        }
                    ],
                },
                {
                    "role": "model",
                    "parts": [
                        {
                            "text": (
                                "You can use boolean indexing. What specific"
                                " condition are you filtering by?"
                            )
                        }
                    ],
                },
                {
                    "role": "user",
                    "parts": [
                        {
                            "text": (
                                "I want rows where 'status' is 'active' and"
                                " 'score' is over 80."
                            )
                        }
                    ],
                },
            ]
        },
        "response": {
            "candidates": [
                {
                    "content": {
                        "role": "model",
                        "parts": [
                            {
                                "text": (
                                    "Combine conditions with `&`: `df[(df['status']"
                                    " == 'active') & (df['score'] > 80)]`."
                                )
                            }
                        ],
                    }
                }
            ]
        },
    },
]

# DataFrame 생성
import pandas as pd
df = pd.DataFrame(chat_dataset)

# %% [markdown]
# Refer to following link to check available rubric options
# https://docs.cloud.google.com/gemini-enterprise-agent-platform/models/rubric-metric-details

# %%
from vertexai import Client, types
import render_util
import google.auth
from google.genai import types as genai_types
httpOptions = genai_types.HttpOptions(
    retry_options=genai_types.HttpRetryOptions(
        attempts=5,           # 최대 재시도 횟수
        initial_delay=1.0,    # 첫 대기 시간
        http_status_codes=[429, 500, 502, 503, 504] # 재시도 대상 에러 코드
    )
)
_, PROJECT_ID = google.auth.default()
LOCATION = "global"
client = Client(project=PROJECT_ID, location=LOCATION)

# %%
eval_result = client.evals.evaluate(
        dataset=df,
        metrics=[
            types.RubricMetric.GENERAL_QUALITY,
        ],
        config=types.EvaluateMethodConfig(
            http_options=httpOptions
        )
)
render_util.display_evaluation_result(eval_result)
# Out:
# Computing Metrics for Evaluation Dataset: 100%|██████████| 3/3 [00:25<00:00,  8.63s/it]
#         <iframe
#             width="100%"
#             height="800px"
#             src="data:text/html;charset=utf-8;base64,..."
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
